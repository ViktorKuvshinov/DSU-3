# %% [markdown]
# ### Сделаем оглавление в ноутбуке

# %% [markdown]
# ### Оглавление

# %% [markdown]
# 1. [Задача 1](#task1)
#     1.1 [Подзадача 1](#subtask1)
#     1.2 [Подзадача 2](#subtask2)
#     1.3 [Подзадача 2](#subtask3)
#     1.4 [Подзадача 2](#subtask4)
#     1.5 [Подзадача 2](#subtask5)
# 2. [Задача 2](#task2)

# %% [markdown]
# ### Задача 1
# <a id = 'task1'></a>
